# %% [markdown]
# <a href="https://colab.research.google.com/github/Agim-dudu/Grayscale-Image-With-Average-Methode/blob/main/Grayscale_Image_With_Average_Methode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Apa itu Citra Greyscale**
#
# Suatu citra grayscale adalah suatu citra yang hanya memiliki warna tingkat
# keabuan. Penggunaan citra grayscale dikarenakan membutuhkan sedikit informasi yang diberikan pada tiap piksel dibandingkan dengan citra berwarna. Warna abu-abu
# pada citra grayscale adalah warna R (Red), G (Green), B (Blue) yang memiliki
# intensitas yang sama. Sehingga dalam grayscale image hanya membutuhkan nilai
# intensitas tunggal dibandingkan dengan citra berwarna membutuhkan tiga intensitas
# untuk tiap pikselnya. Intensitas dari citra grayscale disimpan dalam 8 bit integer yang
# memberikan 256 kemungkinan yang mana dimulai dari level 0 sampai dengan 255 (0
# untuk hitam dan 255 untuk putih dan nilai diantaranya adalah derajat keabuan).
# Tingkat keabuan atau Grayscale level dapat dilihat pada **gambar 2.1**.
#
# ![image.png](data:image/png;base64,...)
#
# # **Metode Rata-Rata**
#
# Metode average untuk mengonversi gambar berwarna (RGB) menjadi gambar grayscale adalah salah satu metode paling sederhana. Dalam metode ini, nilai grayscale dihitung dengan mengambil rata-rata nilai dari ketiga komponen warna (merah, hijau, dan biru) dari setiap piksel. Langkah-langkah yang dilakukan adalah sebagai berikut:
#
# ## **1. Ambil Komponen Warna RGB:**
# Setiap piksel dalam gambar RGB terdiri dari tiga nilai: R (merah), G (hijau), dan B (biru). Masing-masing nilai biasanya berkisar dari 0 hingga 255.
# ## **2. Hitung Nilai Rata-Rata:**
# Nilai grayscale dari setiap piksel dihitung dengan mengambil rata-rata dari ketiga komponen warna tersebut:
# ![image.png](data:image/png;base64,...)
#
# ## **3. Tetapkan Nilai Grayscale ke Piksel:**
# Nilai rata-rata yang diperoleh kemudian digunakan sebagai nilai grayscale dari piksel tersebut. Jadi, piksel tersebut diubah dari (R, G, B) menjadi (Gray, Gray, Gray), di mana semua komponen warna memiliki nilai yang sama, yaitu nilai grayscale yang telah dihitung.
#
# # **Contoh Perhitungan:**
# Misalkan kita memiliki sebuah piksel dengan nilai RGB berikut:
#
#
# *   R = 100
# *   G = 150
# *   B = 200
#
#
# Nilai grayscale untuk piksel tersebut dapat dihitung sebagai berikut:
#
# ![image.png](data:image/png;base64,...)
#
# Jadi, nilai grayscale dari piksel ini adalah 150, dan piksel ini akan menjadi (150, 150, 150) dalam gambar grayscale.
#
# # **Implementasi dalam Python**
# Berikut adalah contoh implementasi metode average menggunakan Python:
#
#
# *   Langkah Pertama Import Library Python :
# ![image.png](data:image/png;base64,...)
# *   Buat Fungsi Untuk Melakukan Grayscale dengan Metode Average :
# ![image.png](data:image/png;base64,...)
# *   Definisikan Path Gambar & Panggil Fungsi Average yang telah dibuat sebelumnya :
# ![image.png](data:image/png;base64,...)
# *   Menampilkan Gambar Sebelum dan Sesudah Grayscale :
# ![image.png](data:image/png;base64,...)
# *   Output Program :
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Silahkan Coba Code Program Pada Cell Dibawah**

# %%
# Coba Disini
